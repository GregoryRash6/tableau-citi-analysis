# %%
import pandas as pd

# %%
# File Path
june_2018 = "june_2018.csv"

# Read CSV
june_2018 = pd.read_csv(june_2018)

# File Path
june_2019 = "june_2019.csv"

# Read CSV
june_2019 = pd.read_csv(june_2019)

# File Path
june_2020 = "june_2020.csv"

# Read CSV
june_2020 = pd.read_csv(june_2020)

# %%
frames = [june_2018, june_2019, june_2020]

result = pd.concat(frames).reset_index(drop=True)

result
# Out:
#          tripduration                 starttime                  stoptime  \
# 0                 569  2018-06-01 01:57:20.5140  2018-06-01 02:06:50.0880
# 1                 480  2018-06-01 02:02:42.3980  2018-06-01 02:10:43.3540
# 2                 692  2018-06-01 02:04:23.6240  2018-06-01 02:15:55.7470
# 3                 664  2018-06-01 03:00:55.4610  2018-06-01 03:11:59.9060
# 4                 818  2018-06-01 06:04:54.4270  2018-06-01 06:18:32.6170
# ...               ...                       ...                       ...
# 5960741           685  2020-06-30 23:59:41.1160  2020-07-01 00:11:06.7790
# 5960742           446  2020-06-30 23:59:46.4260  2020-07-01 00:07:13.0860
# 5960743           439  2020-06-30 23:59:47.4770  2020-07-01 00:07:06.5590
# 5960744           890  2020-06-30 23:59:53.3950  2020-07-01 00:14:43.4270
# 5960745           433  2020-06-30 23:59:53.9010  2020-07-01 00:07:07.0950
#
#          start station id         start station name  start station latitude  \
# ...

# %%
# Copy Unemployment DataFrame
citi_data = result.copy()

# Rename Columns
citi_data = citi_data.rename(columns={"tripduration": "Trip Duration",
                                                         "starttime": "Start Time",
                                                         "stoptime": "Stop Time",
                                                         "start station id": "Start Station ID",
                                                         "start station name": "Start Station Name", 
                                                         "start station latitude": "Start Station Latitude",
                                                         "start station longitude": "Start Station Longitude",
                                                         "end station id": "End Station ID",
                                                         "end station name": "End Station Name",
                                                         "end station latitude": "End Station Latitude",
                                                         "end station longitude": "End Station Longitude",
                                                         "bikeid": "Bike ID",
                                                         "usertype": "User Type",
                                                         "birth year": "Birth Year",
                                                         "gender": "Gender"})

# %%
# Filter Out Years
citi_data = citi_data[citi_data["Birth Year"] >= 1918]

# %%
citi_data['Gender'] = citi_data['Gender'].map({0:'Unknown', 1:'Male', 2:'Female'})

# %%
citi_data
# Out:
#          Trip Duration                Start Time                 Stop Time  \
# 0                  569  2018-06-01 01:57:20.5140  2018-06-01 02:06:50.0880
# 1                  480  2018-06-01 02:02:42.3980  2018-06-01 02:10:43.3540
# 2                  692  2018-06-01 02:04:23.6240  2018-06-01 02:15:55.7470
# 3                  664  2018-06-01 03:00:55.4610  2018-06-01 03:11:59.9060
# 4                  818  2018-06-01 06:04:54.4270  2018-06-01 06:18:32.6170
# ...                ...                       ...                       ...
# 5960741            685  2020-06-30 23:59:41.1160  2020-07-01 00:11:06.7790
# 5960742            446  2020-06-30 23:59:46.4260  2020-07-01 00:07:13.0860
# 5960743            439  2020-06-30 23:59:47.4770  2020-07-01 00:07:06.5590
# 5960744            890  2020-06-30 23:59:53.3950  2020-07-01 00:14:43.4270
# 5960745            433  2020-06-30 23:59:53.9010  2020-07-01 00:07:07.0950
#
# ...

# %%
# Save Finished DataFrame for Project Use
citi_data.to_csv(r"citi_data.csv", index = False)
